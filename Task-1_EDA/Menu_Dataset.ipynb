# %% [markdown]
# # #Dataset 2 :- menu.csv#

# %% [markdown]
# # #1.Data Loading And Preprocessing

# %%
# First We Need To Import Libraries For Further Preprocessing

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Now We See The Data

menu_dataset = pd.read_csv('menu.csv')

# %%
menu_dataset
# Out:
#                Category                                               Item  \
# 0             Breakfast                                       Egg McMuffin
# 1             Breakfast                                  Egg White Delight
# 2             Breakfast                                   Sausage McMuffin
# 3             Breakfast                          Sausage McMuffin with Egg
# 4             Breakfast                   Sausage McMuffin with Egg Whites
# ..                  ...                                                ...
# 255  Smoothies & Shakes                 McFlurry with Oreo Cookies (Small)
# 256  Smoothies & Shakes                McFlurry with Oreo Cookies (Medium)
# 257  Smoothies & Shakes                 McFlurry with Oreo Cookies (Snack)
# 258  Smoothies & Shakes  McFlurry with Reese's Peanut Butter Cups (Medium)
# 259  Smoothies & Shakes   McFlurry with Reese's Peanut Butter Cups (Snack)
#
#         Serving Size  Calories  Calories from Fat  Total Fat  \
# ...

# %%
menu_dataset.describe()
# Out:
#           Calories  Calories from Fat   Total Fat  Total Fat (% Daily Value)  \
# count   260.000000         260.000000  260.000000                 260.000000
# mean    368.269231         127.096154   14.165385                  21.815385
# std     240.269886         127.875914   14.205998                  21.885199
# min       0.000000           0.000000    0.000000                   0.000000
# 25%     210.000000          20.000000    2.375000                   3.750000
# 50%     340.000000         100.000000   11.000000                  17.000000
# 75%     500.000000         200.000000   22.250000                  35.000000
# max    1880.000000        1060.000000  118.000000                 182.000000
#
#        Saturated Fat  Saturated Fat (% Daily Value)   Trans Fat  Cholesterol  \
# count     260.000000                     260.000000  260.000000   260.000000
# mean        6.007692                      29.965385    0.203846    54.942308
# ...

# %%
menu_dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 260 entries, 0 to 259
# Data columns (total 24 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Category                       260 non-null    object
#  1   Item                           260 non-null    object
#  2   Serving Size                   260 non-null    object
#  3   Calories                       260 non-null    int64
#  4   Calories from Fat              260 non-null    int64
#  5   Total Fat                      260 non-null    float64
#  6   Total Fat (% Daily Value)      260 non-null    int64
#  7   Saturated Fat                  260 non-null    float64
#  8   Saturated Fat (% Daily Value)  260 non-null    int64
#  9   Trans Fat                      260 non-null    float64
#  10  Cholesterol                    260 non-null    int64
#  11  Cholesterol (% Daily Value)    260 non-null    int64
# ...

# %%
# now We Clean the dataset

if 'Unnamed: 0' in menu_dataset.columns:
    menu_dataset.drop(['Unnamed: 0'], axis=1, inplace=True)

# %%
# Check Whether any null or missing values is there

menu_dataset.isnull().sum()
# Out:
# Category                         0
# Item                             0
# Serving Size                     0
# Calories                         0
# Calories from Fat                0
# Total Fat                        0
# Total Fat (% Daily Value)        0
# Saturated Fat                    0
# Saturated Fat (% Daily Value)    0
# Trans Fat                        0
# Cholesterol                      0
# Cholesterol (% Daily Value)      0
# Sodium                           0
# Sodium (% Daily Value)           0
# Carbohydrates                    0
# Carbohydrates (% Daily Value)    0
# Dietary Fiber                    0
# Dietary Fiber (% Daily Value)    0
# Sugars                           0
# Protein                          0
# Vitamin A (% Daily Value)        0
# Vitamin C (% Daily Value)        0
# Calcium (% Daily Value)          0
# Iron (% Daily Value)             0
# dtype: int64

# %%
# check Whether any redundant rows

menu_dataset.duplicated().sum()
# Out:
# np.int64(0)

# %%
# check whether the datatypes is correct

menu_dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 260 entries, 0 to 259
# Data columns (total 24 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Category                       260 non-null    object
#  1   Item                           260 non-null    object
#  2   Serving Size                   260 non-null    object
#  3   Calories                       260 non-null    int64
#  4   Calories from Fat              260 non-null    int64
#  5   Total Fat                      260 non-null    float64
#  6   Total Fat (% Daily Value)      260 non-null    int64
#  7   Saturated Fat                  260 non-null    float64
#  8   Saturated Fat (% Daily Value)  260 non-null    int64
#  9   Trans Fat                      260 non-null    float64
#  10  Cholesterol                    260 non-null    int64
#  11  Cholesterol (% Daily Value)    260 non-null    int64
# ...

# %%
# now here we see the serving size that have string so we convert into float

# also removing strings
import re

def extract_serving_size(serving_size_str):
    match = re.search(r'(\d+\.?\d*)', serving_size_str)
    if match:
        return float(match.group(1))
    return None

menu_dataset['Serving Size'] = menu_dataset['Serving Size'].apply(extract_serving_size)

# %%
menu_dataset['Serving Size']
# Out:
# 0       4.8
# 1       4.8
# 2       3.9
# 3       5.7
# 4       5.7
#        ...
# 255    10.1
# 256    13.4
# 257     6.7
# 258    14.2
# 259     7.1
# Name: Serving Size, Length: 260, dtype: float64

# %%
# now We See The whole data

menu_dataset
# Out:
#                Category                                               Item  \
# 0             Breakfast                                       Egg McMuffin
# 1             Breakfast                                  Egg White Delight
# 2             Breakfast                                   Sausage McMuffin
# 3             Breakfast                          Sausage McMuffin with Egg
# 4             Breakfast                   Sausage McMuffin with Egg Whites
# ..                  ...                                                ...
# 255  Smoothies & Shakes                 McFlurry with Oreo Cookies (Small)
# 256  Smoothies & Shakes                McFlurry with Oreo Cookies (Medium)
# 257  Smoothies & Shakes                 McFlurry with Oreo Cookies (Snack)
# 258  Smoothies & Shakes  McFlurry with Reese's Peanut Butter Cups (Medium)
# 259  Smoothies & Shakes   McFlurry with Reese's Peanut Butter Cups (Snack)
#
#      Serving Size  Calories  Calories from Fat  Total Fat  \
# ...

# %% [markdown]
# # #2. Now Calculate the basic statistics

# %%
# now calculate the basic statistics

print("Mean:\n", menu_dataset.mean(numeric_only=True))
print("\nMedian:\n", menu_dataset.median(numeric_only=True))
print("\nMode:\n", menu_dataset.mode(numeric_only=True))
print("\nStandard Deviation:\n", menu_dataset.std(numeric_only=True))
# Out:
# Mean:
#  Serving Size                      12.803077
# Calories                         368.269231
# Calories from Fat                127.096154
# Total Fat                         14.165385
# Total Fat (% Daily Value)         21.815385
# Saturated Fat                      6.007692
# Saturated Fat (% Daily Value)     29.965385
# Trans Fat                          0.203846
# Cholesterol                       54.942308
# Cholesterol (% Daily Value)       18.392308
# Sodium                           495.750000
# Sodium (% Daily Value)            20.676923
# Carbohydrates                     47.346154
# Carbohydrates (% Daily Value)     15.780769
# Dietary Fiber                      1.630769
# Dietary Fiber (% Daily Value)      6.530769
# Sugars                            29.423077
# Protein                           13.338462
# Vitamin A (% Daily Value)         13.426923
# Vitamin C (% Daily Value)          8.534615
# Calcium (% Daily Value)           20.973077
# ...

# %% [markdown]
# # #3. Time-Series analysis ( line chart )

# %% [markdown]
# ##--> this dataset does not contains time so we cant further do time series analysis

# %% [markdown]
# # #4. Customer Analysis

# %%
# Analyze customer demographics and purchasing behavior.

# now we analyze using customer category of eating

menu_dataset['Category'].value_counts()
# Out:
# Category
# Coffee & Tea          95
# Breakfast             42
# Smoothies & Shakes    28
# Chicken & Fish        27
# Beverages             27
# Beef & Pork           15
# Snacks & Sides        13
# Desserts               7
# Salads                 6
# Name: count, dtype: int64

# %% [markdown]
# Here We can see that according to the **category** where there are most buyers are from **coffee** and **tea** and less are **salads**.

# %% [markdown]
# # #5. Visualization: Present insights through bar charts, line plots, and heatmaps.

# %%
# bar charts

menu_dataset['Category'].value_counts().plot(kind='bar')
plt.xlabel('Category')
plt.ylabel('Count')
plt.title('Category Distribution')
plt.show()

# %%
# Heatmap

# Define columns to include for a less redundant correlation heatmap
# Excluding 'Calories' and 'Calories from Fat' as requested, and prioritizing main nutrient values
selected_cols = [
    'Serving Size',
    'Total Fat', 'Saturated Fat', 'Trans Fat',
    'Cholesterol',
    'Sodium',
    'Carbohydrates', 'Dietary Fiber', 'Sugars',
    'Protein',
    'Vitamin A (% Daily Value)', 'Vitamin C (% Daily Value)', 'Calcium (% Daily Value)', 'Iron (% Daily Value)'
]

# Filter the dataset to include only the selected numeric columns
filtered_numeric_menu_dataset = menu_dataset[selected_cols]

correlation_matrix = filtered_numeric_menu_dataset.corr()

plt.figure(figsize=(12, 10)) # Increased figure size for better readability with more labels
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', linewidths=0.5, fmt=".2f")
plt.title('Filtered Correlation Heatmap of Nutrient Values')
plt.show()

# %% [markdown]
# # #6. **Recommendations**

# %% [markdown]
#  recommendations based on the EDA:
#
# -->Nutritional Balance: Several items, particularly from 'Desserts' and 'Smoothies & Shakes' categories, show very high calorie, fat, and sugar content. Consider offering healthier/lighter versions or smaller portion sizes to cater to health-conscious customers.
#
# -->Menu Diversification: Categories like 'Salads' and 'Desserts' have a significantly lower number of items. Expanding the variety in these categories could attract a broader customer base or encourage existing customers to explore more options, potentially increasing sales in these segments.
#
# -->Ingredient Analysis: The heatmap showed strong correlations between various fat components and between carbohydrates and sugars. This suggests that adjustments in core ingredients (e.g., opting for leaner proteins, reducing added sugars) could significantly impact overall nutritional profiles across multiple menu items simultaneously.
#
# -->Promotional Focus: Given that 'Coffee & Tea' and 'Breakfast' are the most popular categories, focus on maintaining their appeal through loyalty programs or seasonal specials. For less popular categories like 'Salads', targeted promotions could help increase their visibility and demand.
